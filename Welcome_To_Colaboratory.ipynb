# %% [markdown]
# <a href="https://colab.research.google.com/github/VanshGarg18/Vansh-Garg/blob/main/Welcome_To_Colaboratory.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
file_path = '/content/WA_Fn-UseC_-Telco-Customer-Churn.csv'
data = pd.read_csv(file_path)

# %%
tenure_gender_data = data[['tenure', 'gender']]

# %%
grouped_data = tenure_gender_data.groupby('gender')['tenure'].mean()

# %%
plt.figure(figsize=(8, 6))
grouped_data.plot(kind='bar', color=['green', 'yellow'])
plt.title('Average Tenure by Gender')
plt.xlabel('Gender')
plt.ylabel('Average Tenure')
plt.xticks(rotation=0)
plt.grid(axis='y')
plt.show()
